# %%
a=10
b=10
a+b
# Out:
# 20

# %%
a%b==0
# Out:
# True

# %%
n=5
i=2
if(i<=(n-i)):
    if(n%i==0):
        print("Not primeee")
    else:   
        i+=1
        print("Prime")
else:
    print(" prime1")
# Out:
# Prime

# %%
p=int(input(  "Enter a number: "))
r=int(input(  "Enter a number: "))
t=int(input(  "Enter a number: "))
si = 0
si =(p*r*t)/100
print(si)
# Out:
# 432.0

# %%
number1 = int(input("Enter a number: "))
number2 = int(input("Enter a number: "))
addition = 0
addition = number + number2
print("The sum is: ", addition)
# Out:
# The sum is:  24

# %%
n = int(input("enter the number: "))
c=1
for i in range(n):
    c = c*(i+1)
    print(c)
# Out:
# 1
# 2
# 6
# 24
# 120
# 720
# 5040
# 40320
# 362880
# 3628800
# 39916800
# 479001600
# 6227020800
# 87178291200
# 1307674368000
# 20922789888000
# 355687428096000
# 6402373705728000
# 121645100408832000
# 2432902008176640000

# %%
age =int(input("enter age : "))
if(age<=18):
    print("No,you cannot get Driving license")
else:
    print("yes, you can get driving license")
# Out:
# No,you cannot get Driving license

# %%
print("Nikunj Rajendra Shetye")
# Out:
# Nikunj Rajendra Shetye

# %%
## this is how we write comments
## comment are mostly in english
