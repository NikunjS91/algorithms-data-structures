# %%
##if-else statement
age = int(input("enter age:"))
if(age<=12):print("child")
elif(age<=19):print("teenager")
elif(age<=21):print("young adult")
elif(age<=30):print("adult")
else:print('senior citizen')
# Out:
# young adult

# %%
number = int(input("enter Number:"))
if(number>=0):print(f"{number} is positive number")
else: print(f"{number} is negative number")
# Out:
# -12 is negative number

# %%
number = int(input("enter Number:"))
if(number%2==0):print(F"{number} is even")
else:print(F"{number} is odd")
# Out:
# 22 is even

# %%
marks = int(input('Enter Your Marks'))
if(marks>=90):print('A grade')
elif((marks>=80)&(marks<=90)):print('B grade')
else:print("C grade")
# Out:
# B grade

# %%
char = (input('enter char :'))
if(char.isupper()):print('the char is Upper case')
else:print('the char is lower case')
# Out:
# the char is lower case

# %%
char = (input('enter char :'))
a = ord(char)
print("ascii value is : ",a)
if((a>=97)&(a<=122)):print(f'{char} is lower case character')
elif((a>=65)&(a<=90)):print(f'{char} is Uppercase character')
else:print('not a character')
# Out:
# ascii value is :  97
# a is lower case character

# %%
#ternary statement python
age =int(input("enter age : "))
result = 'adult ' if age>=18 else 'not an adult'
print(result)
# Out:
# adult

# %%
numbers = [1,2,3,4,5,6]
result = ['even' if i%2==0 else 'odd' for i in numbers]
print(result)
# Out:
# ['odd', 'even', 'odd', 'even', 'odd', 'even']

# %%
#loops

# %%
number =[1,2,3,4,5,6]
for i in number:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#while loop

# %%
num = 1
while num<=5:
    print(num)
    num+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
number = int(input('enter the number till where you want to print on screen'))
i=1
while(i<=number):
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(6):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
num = int(input('enter number : '))
sum=0
for i in range(1,num+1):
    sum = sum+i
print(sum)
# Out:
# 15

# %%
#sum of all odd numbers from 1 to n
num =int(input("enter the n: "))
sum = 0
for i in range(1,num+1):
    if (i%2!=0):
        sum +=i
print(f'sum of all odd number till {num} is {sum}')
# Out:
# sum of all odd number till 10 is 25

# %%
num =int(input("enter the n: "))
sum=0
i=1
while(i<=num):
    if(i%2==0):
        sum=sum +i
    i+=1
print(sum)
# Out:
# 30

# %%
num =20
sum =0
for i in range(1,num+1):
    if(i%2==0):
        
        sum+=1
print(sum)
# Out:
# 10

# %%
##do while loop
## there is no do-while loop in python
## do while ion native programming is the loop atleast runs once then it check the condition,we do it other way here check below code.

# %%
running = True
while running:
    # Body runs at least once
    user_input = input("Enter a positive number (0 to quit): ")
    
    # Update condition
    if int(user_input) <= 0:
        running = False

# %%
n=int(input(":"))

for i in range(2,n):
    #print(i)
    if(n%i==0):
        isPrime=False
        break
    else:
        isPrime=True
if(isPrime):
    print("Prime")
else:
    print('Not-Prime')
# Out:
# Prime

# %%
#nested loop

# %%
for i in range(1,6):
    print('A'*5)
    a=5
    for j in range(a):
        m=10   
        print('*'*m)
# Out:
# AAAAA
# **********
# **********
# **********
# **********
# **********
# AAAAA
# **********
# **********
# **********
# **********
# **********
# AAAAA
# **********
# **********
# **********
# **********
# **********
# AAAAA
# **********
# **********
# **********
# **********
# **********
# AAAAA
# **********
# **********
# **********
# **********
# **********

# %%
##Homework questions

# %%
## sum of all numbers from 1 to n which is divisible by 3

num = int(input("enter the number till the odd number must printed : "))
sum = 0
for i in range(1,num+1):
    if(i%3==0):
        sum = sum + i
print(sum)
# Out:
# 63

# %%
## print factorial of a number N
num = int(input("enter the number : "))
factorial=1
for i in range(1,num+1):
    factorial= factorial*i
print(factorial)
# Out:
# 40320
