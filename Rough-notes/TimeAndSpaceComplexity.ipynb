# %% [markdown]
# ## Time Complexity

# %% [markdown]
# Time complexity is measured as growth of a ducntion with respect to the input value.
# example if a function for input size 1 had 1 operation value. and for input 10 it will be 10 operations
# this is linear, meaning as the n grows the operation grows same as n value(input)

# %% [markdown]
# # What is BigO?

# %%
it is a simple notation as we all put Dollar before the number,
likewise Big O is the notation for a worst case scenario.

also in case of we got an equation of a function then we follow 2 rules:
first ignore the constants
second use only the large terms
third try putting values in all terms before eliminating the larger terms.

# %% [markdown]
# # Types of time complexies

# %%
there are three types of complexities,no one cares of other two but mostly while interview they ask only time complexity.
first is worst case -- Big(O) -- Upper Bound 
second is theta-- O- -- ave case
third is best case -- -()- --lower bound

# %% [markdown]
# # Space Complexity

# %%
Space Complexity is the amount of space taken my an algorithm as function of input size(n).
in this space complexity there happend to have two things in case of a function input space and second is auxilary space.
we only take auxilary space as important factor.
