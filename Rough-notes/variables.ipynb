# %%
##This returns only non-floating numbers its called integer.
age =10
type(age)
# Out:
# int

# %%
##This returns value in characters, any thing inside the paranthisis is string
name ="Nikunj Shetye"
type(name)
# Out:
# str

# %%
##This returns value is decimal so its called float there is one more which is called Double basically same but better size capacity
pointer =3.84
type(pointer)
# Out:
# float

# %%
##This returns True or False so its called Boolean
a=10
b=12
type(a<b)
# Out:
# bool

# %%
##This returns list of numbers this is also called array 
##This represent memory with multiple values
arr=[1,2,4,5]
type(arr)
# Out:
# list

# %%
## this is called dictionary which is key pair value where the key in this case is name and value is nikunj.
dict = {name : "nikunj"}
type(dict)
# Out:
# dict

# %%
## this is called set which means just like array but it holds multiple data types inside it.
var = {1,"nikunj","shetye"}
print(var)
type(var)
# Out:
# {1, 'shetye', 'nikunj'}
# set

# %%
a=3.14
b=int(a)
print(b)
print(type(b),type(a))
# Out:
# 3
# <class 'int'> <class 'float'>

# %%
age = int(input("enter age : "))
if age<18:
    print("cannot drive")
else:
    print('can drive')
# Out:
# can drive

# %%
a=2
b=float(a)
print(b)
# Out:
# 2.0

# %%
#&&
#||
#!

# %%
a= int(input('enter a: '))
b= int(input('enter b: '))
print('sum is ', a+b)
# Out:
# sum is  13

# %%
a= int(input('enter a: '))
b= int(input('enter b: '))
print('sum is ', a+b)
if(a<b):
    print('a is smaller then b, so substraction is ',a-b)
else:
    print('difference is : ',a-b)
print('product is : ',a*b)
print('remainder is ',a%b)
print('numerator is : ',a/b)
print("today we did input and output with statements")
# Out:
# sum is  15
# a is smaller then b, so substraction is  -5
# product is :  50
# remainder is  5
# numerator is :  0.5
# today we did input and output with statements
